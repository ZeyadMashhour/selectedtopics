# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import itertools
import keras
# %matplotlib inline
from tensorflow.keras.models import load_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from imblearn.over_sampling import SMOTE
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense,Dropout

# %%
df=pd.read_csv("BankChurners.xls")
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# 1              44  ...        8256.0                  864           7392.0
# 2              36  ...        3418.0                    0           3418.0
# 3              34  ...        3313.0                 2517            796.0
# 4              21  ...        4716.0                    0           4716.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1.335             1144              42                1.625
# 1                 1.541             1291              33                3.714
# 2                 2.594             1887              20                2.333
# 3                 1.405             1171              20                2.333
# 4                 2.175              816              28                2.500
#
#    Avg_Utilization_Ratio  \
# 0                  0.061
# 1                  0.105
# 2                  0.000
# 3                  0.760
# 4                  0.000
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                           0.000093
# 1                                           0.000057
# 2                                           0.000021
# 3                                           0.000134
# 4                                           0.000022
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                            0.99991
# 1                                            0.99994
# 2                                            0.99998
# 3                                            0.99987
# 4                                            0.99998
#
# [5 rows x 23 columns]

# %%
df=df.iloc[:,1:-2] # dropping the first column and the last 2 columns 
df.sample(3)
# Out:
#          Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 3861  Existing Customer            47      M                5   Post-Graduate
# 1980  Existing Customer            37      F                3        Graduate
# 3102  Existing Customer            35      M                4        Graduate
#
#      Marital_Status Income_Category Card_Category  Months_on_book  \
# 3861        Married  Less than $40K          Blue              41
# 1980         Single  Less than $40K          Blue              31
# 3102         Single     $60K - $80K          Blue              22
#
#       Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 3861                         4                       2                      1
# 1980                         3                       3                      4
# 3102                         3                       3                      3
#
#       Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 3861        3532.0                    0           3532.0
# 1980        2005.0                 1517            488.0
# 3102        8717.0                  719           7998.0
#
#       Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 3861                 0.820             3162              56
# 1980                 0.729             2439              61
# 3102                 0.556             2067              59
#
#       Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 3861                0.600                  0.000
# 1980                0.848                  0.757
# 3102                0.595                  0.082

# %%
df.dtypes
# Out:
# Attrition_Flag               object
# Customer_Age                  int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# dtype: object

# %%
df.Attrition_Flag.value_counts()
# Out:
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64

# %%
x=df.drop("Attrition_Flag",axis=1)
y=df.Attrition_Flag


# spliting numerical from object columns
x_num =x[x.select_dtypes(['int64',"float64"]).columns] 
x_obj =pd.get_dummies(x[x.select_dtypes(['object']).columns],drop_first=True)

# %%
# scaling numericals
scaler = MinMaxScaler()
scaler.fit(x_num)
x_scaled = pd.DataFrame(scaler.transform(x_num),columns=x_num.columns,index=x_num.index)
x_num.sample(5)
# Out:
#       Customer_Age  Dependent_count  Months_on_book  Total_Relationship_Count  \
# 6582            47                3              35                         4
# 9722            48                2              37                         3
# 4186            55                2              49                         5
# 4089            42                4              24                         3
# 4438            41                3              37                         3
#
#       Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# 6582                       3                      6        2402.0
# 9722                       3                      2        3594.0
# 4186                       1                      4        3949.0
# 4089                       2                      3        3103.0
# 4438                       3                      3       19402.0
#
#       Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 6582                  628           1774.0                 0.689
# 9722                 1996           1598.0                 0.795
# 4186                 2024           1925.0                 0.667
# 4089                 1783           1320.0                 0.479
# 4438                    0          19402.0                 0.580
#
#       Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 6582             1930              48                0.600
# 9722            14881             109                0.703
# 4186             3495              64                0.882
# 4089             4792              69                0.643
# 4438             1937              51                0.594
#
#       Avg_Utilization_Ratio
# 6582                  0.261
# 9722                  0.555
# 4186                  0.513
# 4089                  0.575
# 4438                  0.000

# %%
# label encoding
x_dum=pd.get_dummies(x[x.select_dtypes(['object']).columns],drop_first=True)
x_dum.sample(9)
# Out:
#       Gender_M  Education_Level_Doctorate  Education_Level_Graduate  \
# 9722         0                          0                         0
# 4554         0                          0                         1
# 7892         0                          0                         0
# 7630         1                          0                         0
# 2986         1                          0                         0
# 6469         0                          1                         0
# 4767         0                          0                         0
# 2611         0                          0                         0
# 9684         1                          0                         1
#
#       Education_Level_High School  Education_Level_Post-Graduate  \
# 9722                            0                              0
# 4554                            0                              0
# 7892                            0                              0
# 7630                            1                              0
# 2986                            1                              0
# 6469                            0                              0
# 4767                            0                              0
# 2611                            0                              0
# 9684                            0                              0
#
#       Education_Level_Uneducated  Education_Level_Unknown  \
# 9722                           0                        1
# 4554                           0                        0
# 7892                           0                        0
# 7630                           0                        0
# 2986                           0                        0
# 6469                           0                        0
# 4767                           0                        1
# 2611                           1                        0
# 9684                           0                        0
#
#       Marital_Status_Married  Marital_Status_Single  Marital_Status_Unknown  \
# 9722                       0                      1                       0
# 4554                       1                      0                       0
# 7892                       1                      0                       0
# 7630                       1                      0                       0
# 2986                       1                      0                       0
# 6469                       0                      1                       0
# 4767                       0                      1                       0
# 2611                       0                      0                       1
# 9684                       1                      0                       0
#
#       Income_Category_$40K - $60K  Income_Category_$60K - $80K  \
# 9722                            0                            0
# 4554                            0                            0
# 7892                            0                            0
# 7630                            0                            0
# 2986                            0                            0
# 6469                            0                            0
# 4767                            0                            0
# 2611                            0                            0
# 9684                            1                            0
#
#       Income_Category_$80K - $120K  Income_Category_Less than $40K  \
# 9722                             0                               1
# 4554                             0                               1
# 7892                             0                               1
# 7630                             0                               0
# 2986                             1                               0
# 6469                             0                               1
# 4767                             0                               0
# 2611                             0                               1
# 9684                             0                               0
#
#       Income_Category_Unknown  Card_Category_Gold  Card_Category_Platinum  \
# 9722                        0                   0                       0
# 4554                        0                   0                       0
# 7892                        0                   0                       0
# 7630                        0                   0                       0
# 2986                        0                   0                       0
# 6469                        0                   0                       0
# 4767                        1                   0                       0
# 2611                        0                   0                       0
# 9684                        0                   0                       0
#
#       Card_Category_Silver
# 9722                     0
# 4554                     0
# 7892                     0
# 7630                     0
# 2986                     0
# 6469                     0
# 4767                     0
# 2611                     0
# 9684                     0

# %%
# concat lableed and scaled
x_prep=pd.concat([x_scaled, x_dum], axis=1)

x_prep.dtypes
# Out:
# Customer_Age                      float64
# Dependent_count                   float64
# Months_on_book                    float64
# Total_Relationship_Count          float64
# Months_Inactive_12_mon            float64
# Contacts_Count_12_mon             float64
# Credit_Limit                      float64
# Total_Revolving_Bal               float64
# Avg_Open_To_Buy                   float64
# Total_Amt_Chng_Q4_Q1              float64
# Total_Trans_Amt                   float64
# Total_Trans_Ct                    float64
# Total_Ct_Chng_Q4_Q1               float64
# Avg_Utilization_Ratio             float64
# Gender_M                            uint8
# Education_Level_Doctorate           uint8
# Education_Level_Graduate            uint8
# Education_Level_High School         uint8
# Education_Level_Post-Graduate       uint8
# Education_Level_Uneducated          uint8
# Education_Level_Unknown             uint8
# Marital_Status_Married              uint8
# Marital_Status_Single               uint8
# Marital_Status_Unknown              uint8
# Income_Category_$40K - $60K         uint8
# Income_Category_$60K - $80K         uint8
# Income_Category_$80K - $120K        uint8
# Income_Category_Less than $40K      uint8
# Income_Category_Unknown             uint8
# Card_Category_Gold                  uint8
# Card_Category_Platinum              uint8
# Card_Category_Silver                uint8
# dtype: object

# %%
y_dum=pd.get_dummies(y,drop_first=True)
y_dum.sample(15)
#y_dum.dtypes
# Out:
#       Existing Customer
# 4965                  0
# 7139                  1
# 3429                  1
# 8863                  0
# 2120                  1
# 5049                  1
# 1921                  1
# 5163                  1
# 3513                  1
# 2208                  1
# 3738                  1
# 9412                  1
# 1423                  1
# 1137                  0
# 68                    1

# %%
###
    ###END OF PRE PROCESSING####
###

# %%
x_prep.dtypes
# Out:
# Customer_Age                      float64
# Dependent_count                   float64
# Months_on_book                    float64
# Total_Relationship_Count          float64
# Months_Inactive_12_mon            float64
# Contacts_Count_12_mon             float64
# Credit_Limit                      float64
# Total_Revolving_Bal               float64
# Avg_Open_To_Buy                   float64
# Total_Amt_Chng_Q4_Q1              float64
# Total_Trans_Amt                   float64
# Total_Trans_Ct                    float64
# Total_Ct_Chng_Q4_Q1               float64
# Avg_Utilization_Ratio             float64
# Gender_M                            uint8
# Education_Level_Doctorate           uint8
# Education_Level_Graduate            uint8
# Education_Level_High School         uint8
# Education_Level_Post-Graduate       uint8
# Education_Level_Uneducated          uint8
# Education_Level_Unknown             uint8
# Marital_Status_Married              uint8
# Marital_Status_Single               uint8
# Marital_Status_Unknown              uint8
# Income_Category_$40K - $60K         uint8
# Income_Category_$60K - $80K         uint8
# Income_Category_$80K - $120K        uint8
# Income_Category_Less than $40K      uint8
# Income_Category_Unknown             uint8
# Card_Category_Gold                  uint8
# Card_Category_Platinum              uint8
# Card_Category_Silver                uint8
# dtype: object

# %%
# # count plot
# for i in df:
#     if i  != "Attrition_Flag" :
#         sns.countplot(x='Attrition_Flag', data=df, hue=i)
#         plt.title(f"Distribution of Income {i} Attrited and Existing Customers")
#         plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x_prep, y_dum, test_size=0.3,shuffle=True, random_state=42)

# %%
# sm = SMOTE(random_state=42)
# x_train_oversampled, y_train_oversampled = sm.fit_resample(x_prep, y_dum)
# x_train_dumsmote = pd.DataFrame(x_train_oversampled, columns=x_prep.columns)

# %%
model = Sequential([
    Dense(64, input_dim=32, activation='relu'),
    Dense(32, kernel_regularizer=regularizers.l2(0.01), activation='relu'),
    Dropout(0.1),
    Dense(1, activation='sigmoid')
])

# compile the model
model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])

# fit the model
history = model.fit(x_prep, y_dum, epochs=150, validation_split = 0.3,shuffle=True, batch_size=32,verbose=1)
# Out:
# Epoch 1/150
# 222/222 [==============================] - 1s 3ms/step - loss: 0.5599 - accuracy: 0.8571 - val_loss: 0.4805 - val_accuracy: 0.8111
# Epoch 2/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.3167 - accuracy: 0.8943 - val_loss: 0.4170 - val_accuracy: 0.8578
# Epoch 3/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.2683 - accuracy: 0.9065 - val_loss: 0.4994 - val_accuracy: 0.8500
# Epoch 4/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.2511 - accuracy: 0.9087 - val_loss: 0.4932 - val_accuracy: 0.8493
# Epoch 5/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.2430 - accuracy: 0.9096 - val_loss: 0.4620 - val_accuracy: 0.8625
# Epoch 6/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.2348 - accuracy: 0.9098 - val_loss: 0.4646 - val_accuracy: 0.8667
# Epoch 7/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.2307 - accuracy: 0.9111 - val_loss: 0.6149 - val_accuracy: 0.8351
# Epoch 8/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.2250 - accuracy: 0.9141 - val_loss: 0.4992 - val_accuracy: 0.8605
# Epoch 9/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.2226 - accuracy: 0.9161 - val_loss: 0.4782 - val_accuracy: 0.8618
# Epoch 10/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.2178 - accuracy: 0.9185 - val_loss: 0.5732 - val_accuracy: 0.8470
# Epoch 11/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.2168 - accuracy: 0.9166 - val_loss: 0.5238 - val_accuracy: 0.8582
# Epoch 12/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.2134 - accuracy: 0.9190 - val_loss: 0.6038 - val_accuracy: 0.8476
# Epoch 13/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.2106 - accuracy: 0.9206 - val_loss: 0.5508 - val_accuracy: 0.8532
# Epoch 14/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.2063 - accuracy: 0.9203 - val_loss: 0.5195 - val_accuracy: 0.8621
# Epoch 15/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.2071 - accuracy: 0.9196 - val_loss: 0.5136 - val_accuracy: 0.8634
# Epoch 16/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.2043 - accuracy: 0.9213 - val_loss: 0.5636 - val_accuracy: 0.8552
# Epoch 17/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.2029 - accuracy: 0.9224 - val_loss: 0.5103 - val_accuracy: 0.8628
# Epoch 18/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1974 - accuracy: 0.9231 - val_loss: 0.4521 - val_accuracy: 0.8786
# Epoch 19/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1981 - accuracy: 0.9235 - val_loss: 0.5637 - val_accuracy: 0.8572
# Epoch 20/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.1978 - accuracy: 0.9213 - val_loss: 0.5200 - val_accuracy: 0.8677
# Epoch 21/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1954 - accuracy: 0.9273 - val_loss: 0.4797 - val_accuracy: 0.8720
# Epoch 22/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.1954 - accuracy: 0.9235 - val_loss: 0.5261 - val_accuracy: 0.8651
# Epoch 23/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.1930 - accuracy: 0.9255 - val_loss: 0.5373 - val_accuracy: 0.8651
# Epoch 24/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.1910 - accuracy: 0.9297 - val_loss: 0.4935 - val_accuracy: 0.8730
# Epoch 25/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1901 - accuracy: 0.9271 - val_loss: 0.5318 - val_accuracy: 0.8671
# Epoch 26/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1916 - accuracy: 0.9279 - val_loss: 0.4608 - val_accuracy: 0.8799
# Epoch 27/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1878 - accuracy: 0.9259 - val_loss: 0.4681 - val_accuracy: 0.8792
# Epoch 28/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.1867 - accuracy: 0.9289 - val_loss: 0.5071 - val_accuracy: 0.8736
# Epoch 29/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1844 - accuracy: 0.9286 - val_loss: 0.5982 - val_accuracy: 0.8628
# Epoch 30/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1846 - accuracy: 0.9300 - val_loss: 0.5734 - val_accuracy: 0.8648
# Epoch 31/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1830 - accuracy: 0.9310 - val_loss: 0.4399 - val_accuracy: 0.8845
# Epoch 32/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1810 - accuracy: 0.9316 - val_loss: 0.6480 - val_accuracy: 0.8565
# Epoch 33/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1821 - accuracy: 0.9319 - val_loss: 0.5525 - val_accuracy: 0.8674
# Epoch 34/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1788 - accuracy: 0.9306 - val_loss: 0.5966 - val_accuracy: 0.8638
# Epoch 35/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1786 - accuracy: 0.9320 - val_loss: 0.5667 - val_accuracy: 0.8690
# Epoch 36/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1758 - accuracy: 0.9328 - val_loss: 0.5173 - val_accuracy: 0.8766
# Epoch 37/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1778 - accuracy: 0.9352 - val_loss: 0.5851 - val_accuracy: 0.8680
# Epoch 38/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1737 - accuracy: 0.9341 - val_loss: 0.4945 - val_accuracy: 0.8802
# Epoch 39/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.1706 - accuracy: 0.9351 - val_loss: 0.5047 - val_accuracy: 0.8782
# Epoch 40/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1693 - accuracy: 0.9374 - val_loss: 0.5862 - val_accuracy: 0.8674
# Epoch 41/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1708 - accuracy: 0.9352 - val_loss: 0.4891 - val_accuracy: 0.8825
# Epoch 42/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1685 - accuracy: 0.9361 - val_loss: 0.4888 - val_accuracy: 0.8835
# Epoch 43/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1678 - accuracy: 0.9357 - val_loss: 0.5462 - val_accuracy: 0.8756
# Epoch 44/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1638 - accuracy: 0.9365 - val_loss: 0.5157 - val_accuracy: 0.8809
# Epoch 45/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1629 - accuracy: 0.9389 - val_loss: 0.6706 - val_accuracy: 0.8664
# Epoch 46/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1620 - accuracy: 0.9403 - val_loss: 0.5599 - val_accuracy: 0.8776
# Epoch 47/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1620 - accuracy: 0.9395 - val_loss: 0.5813 - val_accuracy: 0.8753
# Epoch 48/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1584 - accuracy: 0.9429 - val_loss: 0.5704 - val_accuracy: 0.8750
# Epoch 49/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1580 - accuracy: 0.9419 - val_loss: 0.6803 - val_accuracy: 0.8759
# Epoch 50/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1571 - accuracy: 0.9447 - val_loss: 0.6597 - val_accuracy: 0.8684
# Epoch 51/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1562 - accuracy: 0.9438 - val_loss: 0.4893 - val_accuracy: 0.8881
# Epoch 52/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1529 - accuracy: 0.9450 - val_loss: 0.6458 - val_accuracy: 0.8746
# Epoch 53/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1536 - accuracy: 0.9423 - val_loss: 0.6152 - val_accuracy: 0.8740
# Epoch 54/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1511 - accuracy: 0.9447 - val_loss: 0.6219 - val_accuracy: 0.8819
# Epoch 55/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1506 - accuracy: 0.9440 - val_loss: 0.5684 - val_accuracy: 0.8815
# Epoch 56/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1491 - accuracy: 0.9460 - val_loss: 0.5919 - val_accuracy: 0.8829
# Epoch 57/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1494 - accuracy: 0.9462 - val_loss: 0.6578 - val_accuracy: 0.8779
# Epoch 58/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1468 - accuracy: 0.9457 - val_loss: 0.4879 - val_accuracy: 0.8868
# Epoch 59/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1464 - accuracy: 0.9454 - val_loss: 0.6899 - val_accuracy: 0.8759
# Epoch 60/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1450 - accuracy: 0.9482 - val_loss: 0.6430 - val_accuracy: 0.8812
# Epoch 61/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1424 - accuracy: 0.9484 - val_loss: 0.5560 - val_accuracy: 0.8868
# Epoch 62/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1416 - accuracy: 0.9478 - val_loss: 0.5700 - val_accuracy: 0.8835
# Epoch 63/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1417 - accuracy: 0.9484 - val_loss: 0.5782 - val_accuracy: 0.8868
# Epoch 64/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.1401 - accuracy: 0.9512 - val_loss: 0.6656 - val_accuracy: 0.8799
# Epoch 65/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1394 - accuracy: 0.9485 - val_loss: 0.6203 - val_accuracy: 0.8885
# Epoch 66/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1397 - accuracy: 0.9522 - val_loss: 0.6882 - val_accuracy: 0.8819
# Epoch 67/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.1382 - accuracy: 0.9482 - val_loss: 0.6668 - val_accuracy: 0.8825
# Epoch 68/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1412 - accuracy: 0.9475 - val_loss: 0.7137 - val_accuracy: 0.8809
# Epoch 69/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1362 - accuracy: 0.9517 - val_loss: 0.6672 - val_accuracy: 0.8842
# Epoch 70/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.1359 - accuracy: 0.9540 - val_loss: 0.7888 - val_accuracy: 0.8753
# Epoch 71/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1338 - accuracy: 0.9541 - val_loss: 0.7626 - val_accuracy: 0.8753
# Epoch 72/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1328 - accuracy: 0.9553 - val_loss: 0.7184 - val_accuracy: 0.8845
# Epoch 73/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1301 - accuracy: 0.9541 - val_loss: 0.6842 - val_accuracy: 0.8891
# Epoch 74/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1302 - accuracy: 0.9546 - val_loss: 0.7830 - val_accuracy: 0.8799
# Epoch 75/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1327 - accuracy: 0.9523 - val_loss: 0.6798 - val_accuracy: 0.8855
# Epoch 76/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1306 - accuracy: 0.9544 - val_loss: 0.7488 - val_accuracy: 0.8819
# Epoch 77/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1287 - accuracy: 0.9554 - val_loss: 0.7949 - val_accuracy: 0.8815
# Epoch 78/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1267 - accuracy: 0.9573 - val_loss: 0.7208 - val_accuracy: 0.8878
# Epoch 79/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1283 - accuracy: 0.9571 - val_loss: 0.7930 - val_accuracy: 0.8829
# Epoch 80/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1244 - accuracy: 0.9594 - val_loss: 0.8579 - val_accuracy: 0.8759
# Epoch 81/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.1242 - accuracy: 0.9584 - val_loss: 0.7306 - val_accuracy: 0.8878
# Epoch 82/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.1227 - accuracy: 0.9594 - val_loss: 0.8867 - val_accuracy: 0.8773
# Epoch 83/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.1232 - accuracy: 0.9589 - val_loss: 0.7976 - val_accuracy: 0.8858
# Epoch 84/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.1227 - accuracy: 0.9574 - val_loss: 0.8116 - val_accuracy: 0.8858
# Epoch 85/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1188 - accuracy: 0.9592 - val_loss: 0.8445 - val_accuracy: 0.8832
# Epoch 86/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1193 - accuracy: 0.9604 - val_loss: 0.6690 - val_accuracy: 0.8901
# Epoch 87/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1220 - accuracy: 0.9598 - val_loss: 0.8546 - val_accuracy: 0.8835
# Epoch 88/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1191 - accuracy: 0.9618 - val_loss: 0.9188 - val_accuracy: 0.8763
# Epoch 89/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1183 - accuracy: 0.9612 - val_loss: 0.9250 - val_accuracy: 0.8806
# Epoch 90/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1171 - accuracy: 0.9604 - val_loss: 0.8413 - val_accuracy: 0.8819
# Epoch 91/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1159 - accuracy: 0.9619 - val_loss: 0.8912 - val_accuracy: 0.8825
# Epoch 92/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1166 - accuracy: 0.9616 - val_loss: 0.9473 - val_accuracy: 0.8815
# Epoch 93/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1133 - accuracy: 0.9629 - val_loss: 1.0154 - val_accuracy: 0.8710
# Epoch 94/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1131 - accuracy: 0.9632 - val_loss: 0.8578 - val_accuracy: 0.8852
# Epoch 95/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1122 - accuracy: 0.9630 - val_loss: 0.9459 - val_accuracy: 0.8832
# Epoch 96/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1135 - accuracy: 0.9619 - val_loss: 0.7964 - val_accuracy: 0.8885
# Epoch 97/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1107 - accuracy: 0.9639 - val_loss: 0.8473 - val_accuracy: 0.8855
# Epoch 98/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1134 - accuracy: 0.9636 - val_loss: 0.8738 - val_accuracy: 0.8832
# Epoch 99/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1090 - accuracy: 0.9649 - val_loss: 0.9153 - val_accuracy: 0.8835
# Epoch 100/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1096 - accuracy: 0.9650 - val_loss: 0.9024 - val_accuracy: 0.8878
# Epoch 101/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1084 - accuracy: 0.9629 - val_loss: 0.9634 - val_accuracy: 0.8819
# Epoch 102/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1075 - accuracy: 0.9653 - val_loss: 0.9870 - val_accuracy: 0.8806
# Epoch 103/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1069 - accuracy: 0.9657 - val_loss: 0.9321 - val_accuracy: 0.8858
# Epoch 104/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1053 - accuracy: 0.9666 - val_loss: 0.9335 - val_accuracy: 0.8865
# Epoch 105/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1060 - accuracy: 0.9674 - val_loss: 0.8999 - val_accuracy: 0.8865
# Epoch 106/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1029 - accuracy: 0.9690 - val_loss: 0.9458 - val_accuracy: 0.8858
# Epoch 107/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.9663 - val_loss: 0.9427 - val_accuracy: 0.8891
# Epoch 108/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1043 - accuracy: 0.9687 - val_loss: 1.0610 - val_accuracy: 0.8845
# Epoch 109/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1021 - accuracy: 0.9698 - val_loss: 0.8981 - val_accuracy: 0.8881
# Epoch 110/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1024 - accuracy: 0.9674 - val_loss: 1.0654 - val_accuracy: 0.8852
# Epoch 111/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.1004 - accuracy: 0.9680 - val_loss: 1.1049 - val_accuracy: 0.8825
# Epoch 112/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.1014 - accuracy: 0.9697 - val_loss: 0.9137 - val_accuracy: 0.8842
# Epoch 113/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.1004 - accuracy: 0.9705 - val_loss: 1.0815 - val_accuracy: 0.8806
# Epoch 114/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0999 - accuracy: 0.9708 - val_loss: 1.2642 - val_accuracy: 0.8723
# Epoch 115/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0994 - accuracy: 0.9695 - val_loss: 1.1478 - val_accuracy: 0.8812
# Epoch 116/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0968 - accuracy: 0.9712 - val_loss: 1.0234 - val_accuracy: 0.8852
# Epoch 117/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0982 - accuracy: 0.9702 - val_loss: 1.2004 - val_accuracy: 0.8792
# Epoch 118/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.0950 - accuracy: 0.9718 - val_loss: 1.1381 - val_accuracy: 0.8845
# Epoch 119/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0996 - accuracy: 0.9694 - val_loss: 1.1010 - val_accuracy: 0.8815
# Epoch 120/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0967 - accuracy: 0.9699 - val_loss: 1.0788 - val_accuracy: 0.8825
# Epoch 121/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0960 - accuracy: 0.9704 - val_loss: 1.0908 - val_accuracy: 0.8835
# Epoch 122/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0953 - accuracy: 0.9723 - val_loss: 1.1778 - val_accuracy: 0.8878
# Epoch 123/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0949 - accuracy: 0.9718 - val_loss: 1.1885 - val_accuracy: 0.8812
# Epoch 124/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0948 - accuracy: 0.9685 - val_loss: 1.2543 - val_accuracy: 0.8776
# Epoch 125/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.0923 - accuracy: 0.9709 - val_loss: 1.1164 - val_accuracy: 0.8832
# Epoch 126/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0911 - accuracy: 0.9753 - val_loss: 1.1857 - val_accuracy: 0.8825
# Epoch 127/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0915 - accuracy: 0.9742 - val_loss: 1.3019 - val_accuracy: 0.8825
# Epoch 128/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0917 - accuracy: 0.9722 - val_loss: 1.2382 - val_accuracy: 0.8806
# Epoch 129/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0904 - accuracy: 0.9729 - val_loss: 1.2200 - val_accuracy: 0.8809
# Epoch 130/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0879 - accuracy: 0.9743 - val_loss: 1.2766 - val_accuracy: 0.8806
# Epoch 131/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0890 - accuracy: 0.9743 - val_loss: 1.2870 - val_accuracy: 0.8855
# Epoch 132/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0885 - accuracy: 0.9735 - val_loss: 1.2125 - val_accuracy: 0.8802
# Epoch 133/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0859 - accuracy: 0.9742 - val_loss: 1.1907 - val_accuracy: 0.8838
# Epoch 134/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.0890 - accuracy: 0.9742 - val_loss: 1.2468 - val_accuracy: 0.8855
# Epoch 135/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.0854 - accuracy: 0.9763 - val_loss: 1.2073 - val_accuracy: 0.8838
# Epoch 136/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.0847 - accuracy: 0.9749 - val_loss: 1.2913 - val_accuracy: 0.8852
# Epoch 137/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.0876 - accuracy: 0.9753 - val_loss: 1.2284 - val_accuracy: 0.8871
# Epoch 138/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.0843 - accuracy: 0.9763 - val_loss: 1.2555 - val_accuracy: 0.8845
# Epoch 139/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0866 - accuracy: 0.9749 - val_loss: 1.4145 - val_accuracy: 0.8842
# Epoch 140/150
# 222/222 [==============================] - 0s 1ms/step - loss: 0.0838 - accuracy: 0.9759 - val_loss: 1.4056 - val_accuracy: 0.8802
# Epoch 141/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.0837 - accuracy: 0.9759 - val_loss: 1.2380 - val_accuracy: 0.8858
# Epoch 142/150
# 222/222 [==============================] - 1s 2ms/step - loss: 0.0805 - accuracy: 0.9787 - val_loss: 1.4740 - val_accuracy: 0.8763
# Epoch 143/150
# 222/222 [==============================] - 1s 2ms/step - loss: 0.0823 - accuracy: 0.9759 - val_loss: 1.3700 - val_accuracy: 0.8802
# Epoch 144/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.0806 - accuracy: 0.9791 - val_loss: 1.3466 - val_accuracy: 0.8786
# Epoch 145/150
# 222/222 [==============================] - 0s 2ms/step - loss: 0.0831 - accuracy: 0.9774 - val_loss: 1.2251 - val_accuracy: 0.8878
# Epoch 146/150
# 222/222 [==============================] - 1s 2ms/step - loss: 0.0782 - accuracy: 0.9801 - val_loss: 1.4711 - val_accuracy: 0.8852
# Epoch 147/150
# 222/222 [==============================] - 1s 3ms/step - loss: 0.0817 - accuracy: 0.9773 - val_loss: 1.3647 - val_accuracy: 0.8861
# Epoch 148/150
# 222/222 [==============================] - 1s 3ms/step - loss: 0.0791 - accuracy: 0.9790 - val_loss: 1.2157 - val_accuracy: 0.8898
# Epoch 149/150
# 222/222 [==============================] - 1s 3ms/step - loss: 0.0769 - accuracy: 0.9794 - val_loss: 1.2838 - val_accuracy: 0.8815
# Epoch 150/150
# 222/222 [==============================] - 1s 2ms/step - loss: 0.0781 - accuracy: 0.9795 - val_loss: 1.4560 - val_accuracy: 0.8835

# %%
predictions = model.predict(x_test, batch_size=10, verbose=1)
rounded_predictions = []
for i in predictions:
    if i >= 0.5:
        rounded_predictions.append(1)
    else:
        rounded_predictions.append(0)
        
cm = confusion_matrix(y_true=y_test, y_pred=rounded_predictions)
# Out:
# 304/304 [==============================] - 0s 1ms/step

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.viridis):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    
    print(cm)
    
    thresh = cm.max() / 2
    for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i,j],
        horizontalalignment ="center",
        color="black" if cm[i, j] > thresh else "white")
    
    plt.tight_layout()
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %%
cm_plot_labels = ["attired",'exist']
plot_confusion_matrix(cm=cm, classes=cm_plot_labels, title="confusion matrix")
# Out:
# Confusion matrix, without normalization
# [[ 348  148]
#  [  15 2528]]

# %%
loss_train = history.history['loss']
epochs = range(1,151)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
loss_train = history.history['accuracy']
epochs = range(1,151)
plt.plot(epochs, loss_train, 'g', label='Training accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
from sklearn import metrics

plt.figure()

#curve 1 y_test y_pred
y_pred = model.predict(x_test).ravel()
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred, pos_label=1)
roc_auc = metrics.auc(fpr, tpr)
lw = 2
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--', alpha=0.15)
plt.plot(fpr, tpr, lw=lw, label=f'ROC curve (area = {roc_auc: 0.2f})')
plt.legend(loc="lower right")

#curve 2 x_prep y_dum
y_pred = model.predict(x_prep).ravel()
fpr, tpr, thresholds = metrics.roc_curve(y_dum, y_pred, pos_label=1)
roc_auc = metrics.auc(fpr, tpr)
lw = 2
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--', alpha=0.15)
plt.plot(fpr, tpr, lw=lw, label=f'ROC curve (area = {roc_auc: 0.4f})')
plt.legend(loc="lower right")


plt.xlabel('(1–Specificity) - False Positive Rate')
plt.ylabel('Sensitivity - True Positive Rate')
plt.title(f'Receiver Operating Characteristic')
plt.show()

# %%
# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
